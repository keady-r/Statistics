# %% [markdown]
# <a><img src="images/ATUlogo.png"></a>
# # 1. Title - Outliers Exercise 1 - Create box plots on a single set of axes for all five experiments in the morley data set.

# %% [markdown]
# ## 1. 1. Overview
#
# Outliers are defined as datapoint that appear to be extremely high or extremely low data points relative to the nearest data point [2.]
#
# ## 1. 2. Calculations

# %%
#Importing packages to use numpy, matplotlib(for plots), spicy
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read in the morley data. [1]
data = np.genfromtxt('data/morley.csv', skip_header=1, delimiter=',', deletechars='"')

# Remove the first column.
data = data[:,1:]
# Select the data for the first experiment.
exper_1 = data[:20, 2]
# Select the data for the second experiment.
exper_2 = data[20:40, 2]
# Select the data for the third experiment.
exper_3 = data[40:60, 2]
# Select the data for the fourth experiment.
exper_4 = data[60:80, 2]
# Select the data for the fifth experiment.
exper_5 = data[80:100, 2]
#plot the experiments in a boxplot on a single axes. 
plt.boxplot(np.array([exper_1,exper_2,exper_3,exper_4,exper_5]).T);

### Add axes, titles, color

# %% [markdown]
# ## 1.3. References
#
# 1. Lecture content
# 2. Definition of outliers: https://www.freecodecamp.org/news/what-is-an-outlier-definition-and-how-to-find-outliers-in-statistics/

# %% [markdown]
# # 2. Title : Outliers Exercise 2 - Create box plots for all of the numercial variables in Fisher's Iris Data Set.
#
#
# ## 2.1. Calculations

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as ss

# %%
irisdata = pd.read_csv('data/irisdata.csv')
irisdata.head(10)
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
# 5                 5.4                3.9                 1.7
# 6                 4.6                3.4                 1.4
# 7                 5.0                3.4                 1.5
# 8                 4.4                2.9                 1.4
# 9                 4.9                3.1                 1.5
#
#     petal width in cm        class
# 0                 0.2  Iris-setosa
# 1                 0.2  Iris-setosa
# 2                 0.2  Iris-setosa
# 3                 0.2  Iris-setosa
# 4                 0.2  Iris-setosa
# 5                 0.4  Iris-setosa
# 6                 0.3  Iris-setosa
# ...

# %%
#Remove the non-numerical field  reference 3
irisdata.drop('class', axis=1, inplace=True)
irisdata
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#       petal width in cm
# 0                   0.2
# 1                   0.2
# 2                   0.2
# 3                   0.2
# 4                   0.2
# ..                  ...
# 145                 2.3
# ...

# %%
# Create a box plot.
plt.boxplot(irisdata);

# %% [markdown]
# ## 2.2. References
# 1. Dataset downloaded from : https://archive.ics.uci.edu/ml/datasets/iris
# 2. Lecture content
# 3. How to remove a column for csv file in python: https://www.codespeedy.com/python-remove-a-column-from-a-csv-file-in-pandas/#:~:text=Pandas%20consist%20of%20drop%20function,columns%20from%20the%20CSV%20files.&text=drop%20has%202%20parameters%20ie,is%20used%20to%20specify%20column.

# %% [markdown]
# # 3. Title: Outliers Exercise 3 - Adapt the above code and plots so that the overall plot is inversely propertional and the individual groups are directly proportional.

# %% [markdown]
# ## 3.1. Calculations

# %%
# Extracted from lecture notes

# Create a corresponding series of x&y vectors and add noise.
xs = np.array([np.linspace(i, i + 2.0, 20) for i in range(10)])
ys = np.array([-1.0 * xs[i] + 2 * i for i in range(len(xs))])
ys = ys + np.random.normal(0.0, 1.0, ys.shape)

# Create global list of x and y values.
x = xs.flatten()
y = ys.flatten()

# Plot.
plt.plot(x, y, '.');

# Best fit line slope and y intercept.
m, c = np.polyfit(x, y, 1)

# Create a steadily increasing x range for plotting.
xbestfit = np.linspace(x.min(), x.max(), 1000)

# Create corresponding y values form best fit line.
ybestfit = m * xbestfit + c
# Plot points.
plt.plot(x, y, '.')

# Plot line.
plt.plot(xbestfit, ybestfit);
# Plot the same points, but now with a different colour for each range.
for i in range(len(xs)):
    plt.plot(xs[i], ys[i], '.')
# Same plot but with best fit lines for each category.
for i in range(len(xs)):
    # Plot this category.
    plt.plot(xs[i], ys[i], '.')
    # Fit line to category.
    m, c = np.polyfit(xs[i], ys[i], 1)
    # Create steadily increasing x range for plot.
    xbestfit = np.linspace(xs[i].min(), xs[i].max(), 50)
    # Corresponding y values based on best fit line.
    ybestfit = m * xbestfit + c
    # Plot best fit line for category.
    plt.plot(xbestfit, ybestfit, color='lightgrey');

# %%
# Extracted from lecture notes

# Create a corresponding series of x&y vectors.
xs = np.array([np.linspace(i, i + 2.0, 20) for i in range(10)])
ys = np.array([-1.0 * xs[i] + 2 * i for i in range(len(xs))])
ys = ys + np.random.normal(0.0, 1.0, ys.shape)

# Create global list of x and y values.
x = xs.flatten()
y = ys.flatten()

# Plot.
plt.plot(x, y, '.');

# Best fit line slope and y intercept.
m, c = np.polyfit(x, y, 1)

# Create a steadily increasing x range for plotting.
xbestfit = np.linspace(x.min(), x.max(), 100)

# Create corresponding y values form best fit line.
ybestfit = m / xbestfit + c

# Plot line.
plt.plot(xbestfit, ybestfit);
# Plot the same points, but now with a different colour for each range.
for i in range(len(xs)):
    plt.plot(xs[i], ys[i], '.')
# Same plot but with best fit lines for each category.
for i in range(len(xs)):
    plt.plot(xs[i], ys[i], '.')
    m, c = np.polyfit(xs[i], ys[i], 1)
    xbestfit = np.linspace(xs[i].min(), xs[i].max(), 50)
    ybestfit = m * xbestfit + c
    plt.plot(xbestfit, ybestfit, color='lightgrey');
# Out:
# /var/folders/xv/8n1dmc7x0l5bgn2gtgft5pmh0000gq/T/ipykernel_7858/4250642326.py:22: RuntimeWarning: divide by zero encountered in divide
#   ybestfit = m / xbestfit + c

# %% [markdown]
# ## 3.2. References

# %% [markdown]
# 1. Simpson's Paradox https://en.wikipedia.org/wiki/Simpson%27s_paradox
